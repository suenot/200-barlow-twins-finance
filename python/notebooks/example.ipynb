# %% [markdown]
# # Barlow Twins Finance: Redundancy Reduction
# Learning robust, mathematically orthogonal stock features without negative sampling or momentum targets.

# %%
from model import CNN1DEncoder, BarlowTwins
print('Barlow Twins Components Ready.')
